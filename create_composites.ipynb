# %%
import pandas as pd
import csv

# %%
#open up final data and make a DataFrame including years and their weighted values
with open('/data/final_data_weighted.csv', "r", encoding="utf-8") as f:
    df = pd.read_csv(f, usecols=[1,3,4], header=None)

df.head()

# %%
#collect sentiment values by the issue
abortion_values_8990 = []
welfare_values_8990 = []
bush_values_8990 = []
clinton_values_8990 = []
dole_values_8990 = []
affirmative_action_values_8990 = []
conservative_values_8990 = []
liberal_values_8990 = []
republican_values_8990 = []
democrat_values_8990 = []
gop_values_8990 = []

abortion_values_9091 = []
welfare_values_9091 = []
bush_values_9091 = []
clinton_values_9091 = []
dole_values_9091 = []
affirmative_action_values_9091 = []
conservative_values_9091 = []
liberal_values_9091 = []
republican_values_9091 = []
democrat_values_9091 = []
gop_values_9091 = []

abortion_values_9192 = []
welfare_values_9192 = []
bush_values_9192 = []
clinton_values_9192 = []
dole_values_9192 = []
affirmative_action_values_9192 = []
conservative_values_9192 = []
liberal_values_9192 = []
republican_values_9192 = []
democrat_values_9192 = []
gop_values_9192 = []

abortion_values_9293 = []
welfare_values_9293 = []
bush_values_9293 = []
clinton_values_9293 = []
dole_values_9293 = []
affirmative_action_values_9293 = []
conservative_values_9293 = []
liberal_values_9293 = []
republican_values_9293 = []
democrat_values_9293 = []
gop_values_9293 = []

abortion_values_9394 = []
welfare_values_9394 = []
bush_values_9394 = []
clinton_values_9394 = []
dole_values_9394 = []
affirmative_action_values_9394 = []
conservative_values_9394 = []
liberal_values_9394 = []
republican_values_9394 = []
democrat_values_9394 = []
gop_values_9394 = []

abortion_values_9495 = []
welfare_values_9495 = []
bush_values_9495 = []
clinton_values_9495 = []
dole_values_9495 = []
affirmative_action_values_9495 = []
conservative_values_9495 = []
liberal_values_9495 = []
republican_values_9495 = []
democrat_values_9495 = []
gop_values_9495 = []

abortion_values_9596 = []
welfare_values_9596 = []
bush_values_9596 = []
clinton_values_9596 = []
dole_values_9596 = []
affirmative_action_values_9596 = []
conservative_values_9596 = []
liberal_values_9596 = []
republican_values_9596 = []
democrat_values_9596 = []
gop_values_9596 = []

abortion_values_9697 = []
welfare_values_9697 = []
bush_values_9697 = []
clinton_values_9697 = []
dole_values_9697 = []
affirmative_action_values_9697 = []
conservative_values_9697 = []
liberal_values_9697 = []
republican_values_9697 = []
democrat_values_9697 = []
gop_values_9697 = []

abortion_values_9798 = []
welfare_values_9798 = []
bush_values_9798 = []
clinton_values_9798 = []
dole_values_9798 = []
affirmative_action_values_9798 = []
conservative_values_9798 = []
liberal_values_9798 = []
republican_values_9798 = []
democrat_values_9798 = []
gop_values_9798 = []

abortion_values_9899 = []
welfare_values_9899 = []
bush_values_9899 = []
clinton_values_9899 = []
dole_values_9899 = []
affirmative_action_values_9899 = []
conservative_values_9899 = []
liberal_values_9899 = []
republican_values_9899 = []
democrat_values_9899 = []
gop_values_9899 = []

abortion_values_9900 = []
welfare_values_9900 = []
bush_values_9900 = []
clinton_values_9900 = []
dole_values_9900 = []
affirmative_action_values_9900 = []
conservative_values_9900 = []
liberal_values_9900 = []
republican_values_9900 = []
democrat_values_9900 = []
gop_values_9900 = []

current_keyword = ""
current_years = ""
for i in range(len(df)):
    current_keyword = df.iat[i,4]
    current_years = df.iat[i,3]

    if current_keyword is "abortion":
        if current_years is "1989-1990":
            abortion_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            abortion_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            abortion_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            abortion_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            abortion_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            abortion_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            abortion_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            abortion_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            abortion_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            abortion_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            abortion_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "welfare":
        if current_years is "1989-1990":
            welfare_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            welfare_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            welfare_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            welfare_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            welfare_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            welfare_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            welfare_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            welfare_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            welfare_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            welfare_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            welfare_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "bush":
        if current_years is "1989-1990":
            bush_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            bush_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            bush_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            bush_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            bush_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            bush_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            bush_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            bush_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            bush_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            bush_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            bush_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "clinton":
        if current_years is "1989-1990":
            clinton_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            clinton_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            clinton_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            clinton_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            clinton_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            clinton_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            clinton_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            clinton_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            clinton_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            clinton_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            clinton_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "dole":
        if current_years is "1989-1990":
            dole_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            dole_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            dole_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            dole_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            dole_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            dole_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            dole_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            dole_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            dole_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            dole_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            dole_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "affirmative action":
        if current_years is "1989-1990":
            affirmative_action_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            affirmative_action_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            affirmative_action_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            affirmative_action_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            affirmative_action_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            affirmative_action_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            affirmative_action_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            affirmative_action_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            affirmative_action_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            affirmative_action_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            affirmative_action_values_9900.append(float(df.iat[i,1]))
    
    elif current_keyword is "conservative":
        if current_years is "1989-1990":
            conservative_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            conservative_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            conservative_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            conservative_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            conservative_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            conservative_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            conservative_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            conservative_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            conservative_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            conservative_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            conservative_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "liberal":
        if current_years is "1989-1990":
            liberal_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            liberal_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            liberal_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            liberal_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            liberal_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            liberal_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            liberal_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            liberal_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            liberal_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            liberal_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            liberal_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "republican":
        if current_years is "1989-1990":
            republican_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            republican_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            republican_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            republican_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            republican_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            republican_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            republican_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            republican_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            republican_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            republican_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            republican_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "democrat":
        if current_years is "1989-1990":
            democrat_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            democrat_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            democrat_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            democrat_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            democrat_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            democrat_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            democrat_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            democrat_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            democrat_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            democrat_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            democrat_values_9900.append(float(df.iat[i,1]))

    elif current_keyword is "gop":
        if current_years is "1989-1990":
            gop_values_8990.append(float(df.iat[i,1]))
        elif current_years is "1990-1991":
            gop_values_9091.append(float(df.iat[i,1]))
        elif current_years is "1991-1992":
            gop_values_9192.append(float(df.iat[i,1]))
        elif current_years is "1992-1993":
            gop_values_9293.append(float(df.iat[i,1]))
        elif current_years is "1993-1994":
            gop_values_9394.append(float(df.iat[i,1]))
        elif current_years is "1994-1995":
            gop_values_9495.append(float(df.iat[i,1]))
        elif current_years is "1995-1996":
            gop_values_9596.append(float(df.iat[i,1]))
        elif current_years is "1996-1997":
            gop_values_9697.append(float(df.iat[i,1]))
        elif current_years is "1997-1998":
            gop_values_9798.append(float(df.iat[i,1]))
        elif current_years is "1998-1999":
            gop_values_9899.append(float(df.iat[i,1]))
        elif current_years is "1999-2000":
            gop_values_9900.append(float(df.iat[i,1]))

# %%
#calculate average sentiment on each issue
def average(lst):
    return sum(lst)/len(lst)

abortion_average_8990 = average(abortion_values_8990)
welfare_average_8990 = average(welfare_values_8990)
bush_average_8990 = average(bush_values_8990)
clinton_average_8990 = average(clinton_values_8990)
dole_average_8990 = average(dole_values_8990)
affirmative_action_average_8990 = average(affirmative_action_values_8990)
conservative_average_8990 = average(conservative_values_8990)
liberal_average_8990 = average(liberal_values_8990)
republican_average_8990 = average(republican_values_8990)
democrat_average_8990 = average(democrat_values_8990)
gop_average_8990 = average(gop_values_8990)

abortion_average_9091 = average(abortion_values_9091)
welfare_average_9091 = average(welfare_values_9091)
bush_average_9091 = average(bush_values_9091)
clinton_average_9091 = average(clinton_values_9091)
dole_average_9091 = average(dole_values_9091)
affirmative_action_average_9091 = average(affirmative_action_values_9091)
conservative_average_9091 = average(conservative_values_9091)
liberal_average_9091 = average(liberal_values_9091)
republican_average_9091 = average(republican_values_9091)
democrat_average_9091 = average(democrat_values_9091)
gop_average_9091 = average(gop_values_9091)

abortion_average_9192 = average(abortion_values_9192)
welfare_average_9192 = average(welfare_values_9192)
bush_average_9192 = average(bush_values_9192)
clinton_average_9192 = average(clinton_values_9192)
dole_average_9192 = average(dole_values_9192)
affirmative_action_average_9192 = average(affirmative_action_values_9192)
conservative_average_9192 = average(conservative_values_9192)
liberal_average_9192 = average(liberal_values_9192)
republican_average_9192 = average(republican_values_9192)
democrat_average_9192 = average(democrat_values_9192)
gop_average_9192 = average(gop_values_9192)

abortion_average_9293 = average(abortion_values_9293)
welfare_average_9293 = average(welfare_values_9293)
bush_average_9293 = average(bush_values_9293)
clinton_average_9293 = average(clinton_values_9293)
dole_average_9293 = average(dole_values_9293)
affirmative_action_average_9293 = average(affirmative_action_values_9293)
conservative_average_9293 = average(conservative_values_9293)
liberal_average_9293 = average(liberal_values_9293)
republican_average_9293 = average(republican_values_9293)
democrat_average_9293 = average(democrat_values_9293)
gop_average_9293 = average(gop_values_9293)

abortion_average_9394 = average(abortion_values_9394)
welfare_average_9394 = average(welfare_values_9394)
bush_average_9394 = average(bush_values_9394)
clinton_average_9394 = average(clinton_values_9394)
dole_average_9394 = average(dole_values_9394)
affirmative_action_average_9394 = average(affirmative_action_values_9394)
conservative_average_9394 = average(conservative_values_9394)
liberal_average_9394 = average(liberal_values_9394)
republican_average_9394 = average(republican_values_9394)
democrat_average_9394 = average(democrat_values_9394)
gop_average_9394 = average(gop_values_9394)

abortion_average_9495 = average(abortion_values_9495)
welfare_average_9495 = average(welfare_values_9495)
bush_average_9495 = average(bush_values_9495)
clinton_average_9495 = average(clinton_values_9495)
dole_average_9495 = average(dole_values_9495)
affirmative_action_average_9495 = average(affirmative_action_values_9495)
conservative_average_9495 = average(conservative_values_9495)
liberal_average_9495 = average(liberal_values_9495)
republican_average_9495 = average(republican_values_9495)
democrat_average_9495 = average(democrat_values_9495)
gop_average_9495 = average(gop_values_9495)

abortion_average_9596 = average(abortion_values_9596)
welfare_average_9596 = average(welfare_values_9596)
bush_average_9596 = average(bush_values_9596)
clinton_average_9596 = average(clinton_values_9596)
dole_average_9596 = average(dole_values_9596)
affirmative_action_average_9596 = average(affirmative_action_values_9596)
conservative_average_9596 = average(conservative_values_9596)
liberal_average_9596 = average(liberal_values_9596)
republican_average_9596 = average(republican_values_9596)
democrat_average_9596 = average(democrat_values_9596)
gop_average_9596 = average(gop_values_9596)

abortion_average_9697 = average(abortion_values_9697)
welfare_average_9697 = average(welfare_values_9697)
bush_average_9697 = average(bush_values_9697)
clinton_average_9697 = average(clinton_values_9697)
dole_average_9697 = average(dole_values_9697)
affirmative_action_average_9697 = average(affirmative_action_values_9697)
conservative_average_9697 = average(conservative_values_9697)
liberal_average_9697 = average(liberal_values_9697)
republican_average_9697 = average(republican_values_9697)
democrat_average_9697 = average(democrat_values_9697)
gop_average_9697 = average(gop_values_9697)

abortion_average_9798 = average(abortion_values_9798)
welfare_average_9798 = average(welfare_values_9798)
bush_average_9798 = average(bush_values_9798)
clinton_average_9798 = average(clinton_values_9798)
dole_average_9798 = average(dole_values_9798)
affirmative_action_average_9798 = average(affirmative_action_values_9798)
conservative_average_9798 = average(conservative_values_9798)
liberal_average_9798 = average(liberal_values_9798)
republican_average_9798 = average(republican_values_9798)
democrat_average_9798 = average(democrat_values_9798)
gop_average_9798 = average(gop_values_9798)

abortion_average_9899 = average(abortion_values_9899)
welfare_average_9899 = average(welfare_values_9899)
bush_average_9899 = average(bush_values_9899)
clinton_average_9899 = average(clinton_values_9899)
dole_average_9899 = average(dole_values_9899)
affirmative_action_average_9899 = average(affirmative_action_values_9899)
conservative_average_9899 = average(conservative_values_9899)
liberal_average_9899 = average(liberal_values_9899)
republican_average_9899 = average(republican_values_9899)
democrat_average_9899 = average(democrat_values_9899)
gop_average_9899 = average(gop_values_9899)

abortion_average_9900 = average(abortion_values_9900)
welfare_average_9900 = average(welfare_values_9900)
bush_average_9900 = average(bush_values_9900)
clinton_average_9900 = average(clinton_values_9900)
dole_average_9900 = average(dole_values_9900)
affirmative_action_average_9900 = average(affirmative_action_values_9900)
conservative_average_9900 = average(conservative_values_9900)
liberal_average_9900 = average(liberal_values_9900)
republican_average_9900 = average(republican_values_9900)
democrat_average_9900 = average(democrat_values_9900)
gop_average_9900 = average(gop_values_9900)

# %%
#export values to .csv
with open("./data/composites/abortion.csv", "w", encoding="utf-8", newline="") as f:
    abortion_writer = csv.writer(f)

with open("./data/composites/welfare.csv", "w", encoding="utf-8", newline="") as f:
    welfare_writer = csv.writer(f)

with open("./data/composites/bush.csv", "w", encoding="utf-8", newline="") as f:
    bush_writer = csv.writer(f)

with open("./data/composites/clinton.csv", "w", encoding="utf-8", newline="") as f:
    clinton_writer = csv.writer(f)

with open("./data/composites/dole.csv", "w", encoding="utf-8", newline="") as f:
    dole_writer = csv.writer(f)

with open("./data/composites/affirmative_action.csv", "w", encoding="utf-8", newline="") as f:
    affirmative_action_writer = csv.writer(f)

with open("./data/composites/conservative.csv", "w", encoding="utf-8", newline="") as f:
    conservative_writer = csv.writer(f)

with open("./data/composites/liberal.csv", "w", encoding="utf-8", newline="") as f:
    liberal_writer = csv.writer(f)

with open("./data/composites/republican.csv", "w", encoding="utf-8", newline="") as f:
    republican_writer = csv.writer(f)

with open("./data/composites/democrat.csv", "w", encoding="utf-8", newline="") as f:
    democrat_writer = csv.writer(f)

with open("./data/composites/gop.csv", "w", encoding="utf-8", newline="") as f:
    gop_writer = csv.writer(f)


abortion_writer.writerow("1989-1990", abortion_average_8990)
abortion_writer.writerow("1990-1991", abortion_average_9091)
abortion_writer.writerow("1991-1992", abortion_average_9192)
abortion_writer.writerow("1992-1993", abortion_average_9293)
abortion_writer.writerow("1993-1994", abortion_average_9394)
abortion_writer.writerow("1994-1995", abortion_average_9495)
abortion_writer.writerow("1995-1996", abortion_average_9596)
abortion_writer.writerow("1996-1997", abortion_average_9697)
abortion_writer.writerow("1997-1998", abortion_average_9798)
abortion_writer.writerow("1998-1999", abortion_average_9899)
abortion_writer.writerow("1999-2000", abortion_average_9900)

welfare_writer.writerow("1989-1990", welfare_average_8990)
welfare_writer.writerow("1990-1991", welfare_average_9091)
welfare_writer.writerow("1991-1992", welfare_average_9192)
welfare_writer.writerow("1992-1993", welfare_average_9293)
welfare_writer.writerow("1993-1994", welfare_average_9394)
welfare_writer.writerow("1994-1995", welfare_average_9495)
welfare_writer.writerow("1995-1996", welfare_average_9596)
welfare_writer.writerow("1996-1997", welfare_average_9697)
welfare_writer.writerow("1997-1998", welfare_average_9798)
welfare_writer.writerow("1998-1999", welfare_average_9899)
welfare_writer.writerow("1999-2000", welfare_average_9900)

bush_writer.writerow("1989-1990", bush_average_8990)
bush_writer.writerow("1990-1991", bush_average_9091)
bush_writer.writerow("1991-1992", bush_average_9192)
bush_writer.writerow("1992-1993", bush_average_9293)
bush_writer.writerow("1993-1994", bush_average_9394)
bush_writer.writerow("1994-1995", bush_average_9495)
bush_writer.writerow("1995-1996", bush_average_9596)
bush_writer.writerow("1996-1997", bush_average_9697)
bush_writer.writerow("1997-1998", bush_average_9798)
bush_writer.writerow("1998-1999", bush_average_9899)
bush_writer.writerow("1999-2000", bush_average_9900)

clinton_writer.writerow("1989-1990", clinton_average_8990)
clinton_writer.writerow("1990-1991", clinton_average_9091)
clinton_writer.writerow("1991-1992", clinton_average_9192)
clinton_writer.writerow("1992-1993", clinton_average_9293)
clinton_writer.writerow("1993-1994", clinton_average_9394)
clinton_writer.writerow("1994-1995", clinton_average_9495)
clinton_writer.writerow("1995-1996", clinton_average_9596)
clinton_writer.writerow("1996-1997", clinton_average_9697)
clinton_writer.writerow("1997-1998", clinton_average_9798)
clinton_writer.writerow("1998-1999", clinton_average_9899)
clinton_writer.writerow("1999-2000", clinton_average_9900)

dole_writer.writerow("1989-1990", dole_average_8990)
dole_writer.writerow("1990-1991", dole_average_9091)
dole_writer.writerow("1991-1992", dole_average_9192)
dole_writer.writerow("1992-1993", dole_average_9293)
dole_writer.writerow("1993-1994", dole_average_9394)
dole_writer.writerow("1994-1995", dole_average_9495)
dole_writer.writerow("1995-1996", dole_average_9596)
dole_writer.writerow("1996-1997", dole_average_9697)
dole_writer.writerow("1997-1998", dole_average_9798)
dole_writer.writerow("1998-1999", dole_average_9899)
dole_writer.writerow("1999-2000", dole_average_9900)

affirmative_action_writer.writerow("1989-1990", affirmative_action_average_8990)
affirmative_action_writer.writerow("1990-1991", affirmative_action_average_9091)
affirmative_action_writer.writerow("1991-1992", affirmative_action_average_9192)
affirmative_action_writer.writerow("1992-1993", affirmative_action_average_9293)
affirmative_action_writer.writerow("1993-1994", affirmative_action_average_9394)
affirmative_action_writer.writerow("1994-1995", affirmative_action_average_9495)
affirmative_action_writer.writerow("1995-1996", affirmative_action_average_9596)
affirmative_action_writer.writerow("1996-1997", affirmative_action_average_9697)
affirmative_action_writer.writerow("1997-1998", affirmative_action_average_9798)
affirmative_action_writer.writerow("1998-1999", affirmative_action_average_9899)
affirmative_action_writer.writerow("1999-2000", affirmative_action_average_9900)

conservative_writer.writerow("1989-1990", conservative_average_8990)
conservative_writer.writerow("1990-1991", conservative_average_9091)
conservative_writer.writerow("1991-1992", conservative_average_9192)
conservative_writer.writerow("1992-1993", conservative_average_9293)
conservative_writer.writerow("1993-1994", conservative_average_9394)
conservative_writer.writerow("1994-1995", conservative_average_9495)
conservative_writer.writerow("1995-1996", conservative_average_9596)
conservative_writer.writerow("1996-1997", conservative_average_9697)
conservative_writer.writerow("1997-1998", conservative_average_9798)
conservative_writer.writerow("1998-1999", conservative_average_9899)
conservative_writer.writerow("1999-2000", conservative_average_9900)

liberal_writer.writerow("1989-1990", liberal_average_8990)
liberal_writer.writerow("1990-1991", liberal_average_9091)
liberal_writer.writerow("1991-1992", liberal_average_9192)
liberal_writer.writerow("1992-1993", liberal_average_9293)
liberal_writer.writerow("1993-1994", liberal_average_9394)
liberal_writer.writerow("1994-1995", liberal_average_9495)
liberal_writer.writerow("1995-1996", liberal_average_9596)
liberal_writer.writerow("1996-1997", liberal_average_9697)
liberal_writer.writerow("1997-1998", liberal_average_9798)
liberal_writer.writerow("1998-1999", liberal_average_9899)
liberal_writer.writerow("1999-2000", liberal_average_9900)

republican_writer.writerow("1989-1990", republican_average_8990)
republican_writer.writerow("1990-1991", republican_average_9091)
republican_writer.writerow("1991-1992", republican_average_9192)
republican_writer.writerow("1992-1993", republican_average_9293)
republican_writer.writerow("1993-1994", republican_average_9394)
republican_writer.writerow("1994-1995", republican_average_9495)
republican_writer.writerow("1995-1996", republican_average_9596)
republican_writer.writerow("1996-1997", republican_average_9697)
republican_writer.writerow("1997-1998", republican_average_9798)
republican_writer.writerow("1998-1999", republican_average_9899)
republican_writer.writerow("1999-2000", republican_average_9900)

democrat_writer.writerow("1989-1990", democrat_average_8990)
democrat_writer.writerow("1990-1991", democrat_average_9091)
democrat_writer.writerow("1991-1992", democrat_average_9192)
democrat_writer.writerow("1992-1993", democrat_average_9293)
democrat_writer.writerow("1993-1994", democrat_average_9394)
democrat_writer.writerow("1994-1995", democrat_average_9495)
democrat_writer.writerow("1995-1996", democrat_average_9596)
democrat_writer.writerow("1996-1997", democrat_average_9697)
democrat_writer.writerow("1997-1998", democrat_average_9798)
democrat_writer.writerow("1998-1999", democrat_average_9899)
democrat_writer.writerow("1999-2000", democrat_average_9900)

gop_writer.writerow("1989-1990", gop_average_8990)
gop_writer.writerow("1990-1991", gop_average_9091)
gop_writer.writerow("1991-1992", gop_average_9192)
gop_writer.writerow("1992-1993", gop_average_9293)
gop_writer.writerow("1993-1994", gop_average_9394)
gop_writer.writerow("1994-1995", gop_average_9495)
gop_writer.writerow("1995-1996", gop_average_9596)
gop_writer.writerow("1996-1997", gop_average_9697)
gop_writer.writerow("1997-1998", gop_average_9798)
gop_writer.writerow("1998-1999", gop_average_9899)
gop_writer.writerow("1999-2000", gop_average_9900)

# %%
#collect sentiment values by volume years
v8990 = []
v9091 = []
v9192 = []
v9293 = []
v9394 = []
v9495 = []
v9596 = []
v9697 = []
v9798 = []
v9899 = []
v9900 = []

current_years = ""
for i in range(len(df)):
    current_years = df.iat[i,3]
